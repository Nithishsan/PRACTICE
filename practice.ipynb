# %%
import pandas as pd

# %%
df = pd.read_csv("/content/netflix_titles_nov_2019.csv")
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
df.iloc[3]
# Out:
# show_id                                                  81082007
# title                                                   Atlantics
# director                                                Mati Diop
# cast            Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# country                                  France, Senegal, Belgium
# date_added                                      November 29, 2019
# release_year                                                 2019
# rating                                                      TV-14
# duration                                                  106 min
# listed_in        Dramas, Independent Movies, International Movies
# description     Arranged to marry a rich man, young Ada is cru...
# type                                                        Movie
# Name: 3, dtype: object

# %%
df.iloc[67:89]
# Out:
#      show_id                            title                   director  \
# 67  70053833                 Black Snake Moan               Craig Brewer
# 68  70122722                         Carriers  Àlex Pastor, David Pastor
# 69  81217738                        Dorasaani               KVR Mahendra
# 70  80081990                     Dream/Killer               Andrew Jenks
# 71  60004471                        Evolution               Ivan Reitman
# 72  60022413                   Eye for an Eye           John Schlesinger
# 73  81011957                  Holiday Secrets                        NaN
# 74  70058022                          Hot Rod             Akiva Schaffer
# 75  60022502                     It Takes Two               Andy Tennant
# 76  80244683       Lorena, Light-Footed Woman          Juan Carlos Rulfo
# 77  80028357                      Love, Rosie           Christian Ditter
# 78  81217739                        Mallesham                      Raj R
# ...

# %%
df.iloc[65:83:3]
# Out:
#      show_id                   title                   director  \
# 65  70003046             Bebe's Kids             Bruce W. Smith
# 68  70122722                Carriers  Àlex Pastor, David Pastor
# 71  60004471               Evolution               Ivan Reitman
# 74  70058022                 Hot Rod             Akiva Schaffer
# 77  80028357             Love, Rosie           Christian Ditter
# 80  70117289  She's Out of My League            Jim Field Smith
#
#                                                  cast  \
# 65  Faizon Love, Vanessa Bell Calloway, Wayne Coll...
# 68  Lou Taylor Pucci, Chris Pine, Piper Perabo, Em...
# 71  David Duchovny, Julianne Moore, Orlando Jones,...
# 74  Andy Samberg, Jorma Taccone, Bill Hader, Danny...
# 77  Lily Collins, Sam Claflin, Christian Cooke, Ja...
# 80  Jay Baruchel, Alice Eve, T.J. Miller, Mike Vog...
#
#                     country         date_added  release_year rating duration  \
# ...

# %%
df.iloc[567:789:5]
# Out:
#       show_id                                              title  \
# 567  81132439                                     Travel Mates 2
# 572  70281312                                      The Blacklist
# 577  80991316                                         Avengement
# 582  80058248                                         I Am Wrath
# 587  70143865                                         Pawn Stars
# 592  81176196                                       The Rap Game
# 597  81092328                                American Warfighter
# 602  81095103  Kabaneri of the Iron Fortress: The Battle of U...
# 607  81002412                                          Tall Girl
# 612  80153467                                       Unbelievable
# 617  81060174                             Bill Burr: Paper Tiger
# 622  70302573                                   Sword Art Online
# 627  81113928                              Care of Kancharapalem
# ...

# %%
df.iloc[:,1:5]
# Out:
#                                     title                    director  \
# 0                               Chocolate                         NaN
# 1     Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                         The Zoya Factor             Abhishek Sharma
# 3                               Atlantics                   Mati Diop
# 4                         Chip and Potato                         NaN
# ...                                   ...                         ...
# 5832          Mad Ron's Prevues from Hell                  Jim Monaco
# 5833                             Splatter                   Joe Dante
# 5834              Just Another Love Story                Ole Bornedal
# 5835                      Dinner for Five                         NaN
# 5836                 To and From New York        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# ...

# %%
df.iloc[45:100,::-1]
# Out:
#        type                                        description  \
# 45    Movie  Thrust from a violent home into a brutal custo...
# 46  TV Show  When she gets angry, middle schooler Naoko tur...
# 47  TV Show  Eight stories celebrating family, faith, love ...
# 48    Movie  The girls of Ōarai High must face off against ...
# 49  TV Show  Two sisters discover disturbing family secrets...
# 50    Movie  Mike Birbiglia performs in this live concert s...
# 51  TV Show  It's the "Nailed It!" holiday special you've b...
# 52  TV Show  Ride along as police officers and drug smuggle...
# 53  TV Show  A new guardian "angelus" uncovers a secret beh...
# 54    Movie  Featuring interviews and vintage footage, this...
# 55  TV Show  Peer into the lives of young Singaporeans as t...
# 56  TV Show  An extraordinary discovery inspires two human ...
# 57  TV Show  As Queen Poppy welcomes a new time of peace in...
# 58    Movie  On board Russia's first nuclear ballistic subm...
# ...

# %%
df.iloc[[7,45,66,78,86,88,99,103],[5,8,11,10]]
# Out:
#             date_added  duration     type  \
# 7    November 29, 2019   107 min    Movie
# 45   November 22, 2019    97 min    Movie
# 66   November 20, 2019    86 min    Movie
# 78   November 20, 2019   131 min    Movie
# 86   November 20, 2019    89 min    Movie
# 88   November 20, 2019    87 min    Movie
# 99   November 17, 2019  1 Season  TV Show
# 103  November 16, 2019    84 min    Movie
#
#                                            description
# 7    The life and times of iconic South African lib...
# 45   Thrust from a violent home into a brutal custo...
# 66   This documentary charts the rise and fall of h...
# 78   A self-trained engineer risks debt, love and r...
# 86   Hired to rescue a flagging car dealership duri...
# 88   Raised on an ashram in India, a self-styled lo...
# 99   When a wardrobe malfunction goes viral, a bubb...
# 103  America's most beloved ventriloquist hits the ...

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
df.set_index("title")
# Out:
#                                       show_id                    director  \
# title
# Chocolate                            81193313                         NaN
# Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
# The Zoya Factor                      81213894             Abhishek Sharma
# Atlantics                            81082007                   Mati Diop
# Chip and Potato                      80213643                         NaN
# ...                                       ...                         ...
# Mad Ron's Prevues from Hell          70141644                  Jim Monaco
# Splatter                             70127998                   Joe Dante
# Just Another Love Story              70084180                Ole Bornedal
# Dinner for Five                      70157452                         NaN
# To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
df.set_index("title",inplace=True)

# %%
df
# Out:
#                                       show_id                    director  \
# title
# Chocolate                            81193313                         NaN
# Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
# The Zoya Factor                      81213894             Abhishek Sharma
# Atlantics                            81082007                   Mati Diop
# Chip and Potato                      80213643                         NaN
# ...                                       ...                         ...
# Mad Ron's Prevues from Hell          70141644                  Jim Monaco
# Splatter                             70127998                   Joe Dante
# Just Another Love Story              70084180                Ole Bornedal
# Dinner for Five                      70157452                         NaN
# To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
df.loc[df.index[1], ["cast"]]
df.loc["To and From New York", ["cast"]]
# Out:
# cast    Barbara King, Shaana Diya, John Krisiukenas, Y...
# Name: To and From New York, dtype: object

# %%
df.loc[df.index[3:90],["cast"]]
# Out:
#                                                                                      cast
# title
# Atlantics                               Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# Chip and Potato                         Abigail Oliver, Andrea Libman, Briana Buckmast...
# Crazy people                            Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# I Lost My Body                          Hakim Faris, Victoire Du Bois, Patrick d'Assum...
# Kalushi: The Story of Solomon Mahlangu  Thabo Rametsi, Thabo Malema, Welile Nzuza, Jaf...
# ...                                                                                   ...
# The Gift                                Cate Blanchett, Giovanni Ribisi, Keanu Reeves,...
# The Goods: Live Hard, Sell Hard         Jeremy Piven, Ving Rhames, James Brolin, David...
# The Longest Yard                        Burt Reynolds, Eddie Albert, Ed Lauter, James ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5837 entries, Chocolate to To and From New York
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   director      3936 non-null   object
#  2   cast          5281 non-null   object
#  3   country       5410 non-null   object
#  4   date_added    5195 non-null   object
#  5   release_year  5837 non-null   int64
#  6   rating        5827 non-null   object
#  7   duration      5837 non-null   object
#  8   listed_in     5837 non-null   object
#  9   description   5837 non-null   object
#  10  type          5837 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 676.3+ KB

# %%
df.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
df
# Out:
#                                       show_id                    director  \
# title
# Chocolate                            81193313                         NaN
# Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
# The Zoya Factor                      81213894             Abhishek Sharma
# Atlantics                            81082007                   Mati Diop
# Chip and Potato                      80213643                         NaN
# ...                                       ...                         ...
# Mad Ron's Prevues from Hell          70141644                  Jim Monaco
# Splatter                             70127998                   Joe Dante
# Just Another Love Story              70084180                Ole Bornedal
# Dinner for Five                      70157452                         NaN
# To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
df,df.isnull()
# Out:
# (                                      show_id                    director  \
#  title
#  Chocolate                            81193313                         NaN
#  Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
#  The Zoya Factor                      81213894             Abhishek Sharma
#  Atlantics                            81082007                   Mati Diop
#  Chip and Potato                      80213643                         NaN
#  ...                                       ...                         ...
#  Mad Ron's Prevues from Hell          70141644                  Jim Monaco
#  Splatter                             70127998                   Joe Dante
#  Just Another Love Story              70084180                Ole Bornedal
#  Dinner for Five                      70157452                         NaN
#  To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
df.describe(include="all")
# Out:
#              show_id                director                cast  \
# count   5.837000e+03                    3936                5281
# unique           NaN                    3108                5087
# top              NaN  Raúl Campos, Jan Suter  David Attenborough
# freq             NaN                      18                  18
# mean    7.730079e+07                     NaN                 NaN
# std     9.479777e+06                     NaN                 NaN
# min     2.698800e+05                     NaN                 NaN
# 25%     8.004520e+07                     NaN                 NaN
# 50%     8.016353e+07                     NaN                 NaN
# 75%     8.024188e+07                     NaN                 NaN
# max     8.122720e+07                     NaN                 NaN
#
#               country        date_added  release_year rating  duration  \
# count            5410              5195   5837.000000   5827      5837
# ...

# %%
df["release_year"].unique()
# Out:
# array([2019, 2018, 2016, 2017, 2001, 2008, 2015, 1980, 1973, 2012, 1987,
#        2002, 2013, 1996, 1992, 2007, 2009, 1995, 2014, 1968, 2010, 1999,
#        2011, 2000, 1974, 1997, 1993, 2006, 2005, 2003, 2004, 2020, 1998,
#        1960, 1958, 1965, 1956, 1978, 1990, 1976, 1962, 1955, 1972, 1991,
#        1988, 1986, 1989, 1975, 1985, 1984, 1970, 1994, 1982, 1983, 1967,
#        1981, 1979, 1925, 1946, 1977, 1959, 1966, 1971, 1963, 1969, 1945,
#        1942, 1944, 1947, 1943, 1954])

# %%
df["release_year"].nunique()
# Out:
# 71

# %%
df["director"].unique()
# Out:
# array([nan, 'Luis Ara, Ignacio Jaunsolo', 'Abhishek Sharma', ...,
#        'Jim Monaco', 'Ole Bornedal', 'Sorin Dan Mihalcescu'], dtype=object)

# %%
df.shape
# Out:
# (5837, 11)

# %%
df
# Out:
#                                       show_id                    director  \
# title
# Chocolate                            81193313                         NaN
# Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
# The Zoya Factor                      81213894             Abhishek Sharma
# Atlantics                            81082007                   Mati Diop
# Chip and Potato                      80213643                         NaN
# ...                                       ...                         ...
# Mad Ron's Prevues from Hell          70141644                  Jim Monaco
# Splatter                             70127998                   Joe Dante
# Just Another Love Story              70084180                Ole Bornedal
# Dinner for Five                      70157452                         NaN
# To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5837 entries, Chocolate to To and From New York
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   director      3936 non-null   object
#  2   cast          5281 non-null   object
#  3   country       5410 non-null   object
#  4   date_added    5195 non-null   object
#  5   release_year  5837 non-null   int64
#  6   rating        5827 non-null   object
#  7   duration      5837 non-null   object
#  8   listed_in     5837 non-null   object
#  9   description   5837 non-null   object
#  10  type          5837 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 676.3+ KB

# %%
df.count()
# Out:
# show_id         5837
# director        3936
# cast            5281
# country         5410
# date_added      5195
# release_year    5837
# rating          5827
# duration        5837
# listed_in       5837
# description     5837
# type            5837
# dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       1937
# TV-14       1593
# TV-PG        678
# R            439
# PG-13        227
# NR           218
# PG           160
# TV-Y7        156
# TV-G         147
# TV-Y         139
# TV-Y7-FV      92
# G             32
# UR             7
# NC-17          2
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# United States                                           1907
# India                                                    697
# United Kingdom                                           336
# Japan                                                    168
# Canada                                                   139
#                                                         ...
# Norway, Denmark, Netherlands, Sweden                       1
# Ireland, United Kingdom, Greece, France, Netherlands       1
# Israel, Germany                                            1
# Canada, Germany, France, United States                     1
# Spain, Mexico, France                                      1
# Name: count, Length: 527, dtype: int64
